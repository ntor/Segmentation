# %%
import torch
import ClassFiles.Networks as net
import ClassFiles.GeneratedDataset as dat
import ClassFiles.Training as train
import ClassFiles.DeepSegmentation as rec
from torch.utils.data import DataLoader
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

clean_image_dataset = dat.ImageDataset("./Neural_Networks_lunglike/eval", "clean")
dirty_image_dataset = dat.ImageDataset("./Neural_Networks_lunglike/eval", "dirty")
cv_seg_dataset = dat.SegmentationDataset("./Neural_Networks_lunglike/eval", "chan-vese")
clean_seg_dataset = dat.SegmentationDataset("./Neural_Networks_lunglike/eval", "clean")


NN = net.ConvNet8(1, 128, 128)
NN.load_state_dict(torch.load("./Neural_Networks_lunglike/ConvNet8_trained", map_location = torch.device("cpu")))

for i in range(200):
    image_number = i

    dirty_im = Image.fromarray(
        255 * dirty_image_dataset.__getitem__(image_number)[0].numpy()
    ).convert("L")
    cv_seg = cv_seg_dataset.__getitem__(image_number)
    clean_seg = clean_seg_dataset.__getitem__(image_number)

    reconstruction = rec.DeepSegmentation(dirty_im, NN, clean_seg)
    plt.close()
    reconstruction.save_segmentation(f'{image_number:03}'+'_clean', path = "./Neural_Networks_lunglike/Contour_Images/ConvNet8_trained")
    plt.close()
    
    reconstruction = rec.DeepSegmentation(dirty_im, NN, cv_seg)
    plt.close()
    reconstruction.save_segmentation(f'{image_number:03}'+'_cv', path = "./Neural_Networks_lunglike/Contour_Images/ConvNet8_trained")
    plt.close()

    reconstruction.run(2000, lmb_reg=14, epsilon=0.1, show_iterations=True)
    plt.close()
    reconstruction.save_segmentation(f'{image_number:03}'+'_rec_cv', path = "./Neural_Networks_lunglike/Contour_Images/ConvNet8_trained")
    plt.close()
    
    reconstruction = rec.DeepSegmentation(dirty_im, NN)
    plt.close()
    reconstruction.run(2000, lmb_reg=14, epsilon=0.1, show_iterations=True)
    plt.close()
    reconstruction.save_segmentation(f'{image_number:03}'+'_rec_random', path = "./Neural_Networks_lunglike/Contour_Images/ConvNet8_trained")
    plt.close()
# Out:
# /Users/lucashuysmans/Documents/GitHub/Segmentation/ClassFiles/DeepSegmentation.py:42: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# ...
#  26%|██▌       | 522/2000 [00:40<01:53, 13.00it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5334c176165c> in <module>
#      37     plt.close()
#      38
# ---> 39     reconstruction.run(2000, lmb_reg=14, epsilon=0.1, show_iterations=True)
#      40     plt.close()
#      41     reconstruction.save_segmentation(f'{image_number:03}'+'_rec_cv', path = "./Neural_Networks_lunglike/Contour_Images")
#
# ~/Documents/GitHub/Segmentation/ClassFiles/DeepSegmentation.py in run(self, steps, lmb_reg, epsilon, show_iterations)
#     104         for i in step_range:
#     105             self.update_c()
# --> 106             self.single_step(lmb_reg, epsilon)
#     107
#
# ...
