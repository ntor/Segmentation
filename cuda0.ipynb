# %%
import torch
import ClassFiles.networks as net
import ClassFiles.networks2 as net2
import ClassFiles.GeneratedDataset as dat
import ClassFiles.Training as train
import ClassFiles.DeepSegmentation as rec
from torch.utils.data import DataLoader
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
train_clean_image_dataset = dat.ImageDataset("/nfs/st01/hpc-cmih-cbs31/lh568/data/train", "clean")
train_cv_image_dataset = dat.ImageDataset("/nfs/st01/hpc-cmih-cbs31/lh568/data/train", "chan-vese")

train_clean_image_dataloader = DataLoader(train_clean_image_dataset, batch_size=100, pin_memory = True, shuffle = True)
train_cv_image_dataloader = DataLoader(train_cv_image_dataset, batch_size=100, pin_memory = True, shuffle = True)

# %%
NN = net2.ConvNet8(1, 128, 128)
NN.load_state_dict(torch.load('ConvNet8_trained_evenmore_v2'))

train.train_regulariser(NN, train_clean_image_dataloader, train_cv_image_dataloader,
                       epochs = 100, lr = 0.00007, mu = 10, binary = True, flip = False, device = "cuda:0",
                       save_path = "cuda0_tempnet")
# Out:
# Wasserstein loss: -31.68	 Gradient Loss: 0.68	 Min Groundtruth: -52.36	 Max Chan-Vese: 31.04
# Wasserstein loss: -34.50	 Gradient Loss: 0.69	 Min Groundtruth: -36.03	 Max Chan-Vese: 33.71
# Wasserstein loss: -32.75	 Gradient Loss: 0.69	 Min Groundtruth: -49.09	 Max Chan-Vese: 31.95
# Wasserstein loss: -36.27	 Gradient Loss: 1.10	 Min Groundtruth: -42.84	 Max Chan-Vese: 33.19
# Wasserstein loss: -31.85	 Gradient Loss: 1.04	 Min Groundtruth: -43.85	 Max Chan-Vese: 32.98
# Wasserstein loss: -34.76	 Gradient Loss: 1.13	 Min Groundtruth: -37.81	 Max Chan-Vese: 31.19
# Wasserstein loss: -33.05	 Gradient Loss: 1.12	 Min Groundtruth: -40.25	 Max Chan-Vese: 36.75
# Wasserstein loss: -33.68	 Gradient Loss: 0.94	 Min Groundtruth: -35.12	 Max Chan-Vese: 34.71
# Wasserstein loss: -33.66	 Gradient Loss: 1.16	 Min Groundtruth: -34.95	 Max Chan-Vese: 35.65
# Wasserstein loss: -34.61	 Gradient Loss: 0.77	 Min Groundtruth: -43.06	 Max Chan-Vese: 36.01
# ...

# %%
train.train_regulariser(NN, train_clean_image_dataloader, train_cv_image_dataloader,
                       epochs = 100, lr = 0.00001, mu = 10, binary = True, flip = False, device = "cuda:0",
                       save_path = "cuda0_tempnet_2")
# Out:
# Wasserstein loss: -37.93	 Gradient Loss: 1.12	 Min Groundtruth: -46.38	 Max Chan-Vese: 34.46
# Wasserstein loss: -40.18	 Gradient Loss: 1.06	 Min Groundtruth: -43.68	 Max Chan-Vese: 36.00
# Wasserstein loss: -37.92	 Gradient Loss: 1.08	 Min Groundtruth: -44.27	 Max Chan-Vese: 35.45
# Wasserstein loss: -36.94	 Gradient Loss: 0.99	 Min Groundtruth: -42.77	 Max Chan-Vese: 36.48
# Wasserstein loss: -37.71	 Gradient Loss: 1.13	 Min Groundtruth: -56.80	 Max Chan-Vese: 31.50
# Wasserstein loss: -34.58	 Gradient Loss: 1.07	 Min Groundtruth: -43.80	 Max Chan-Vese: 34.49
# Wasserstein loss: -35.80	 Gradient Loss: 0.97	 Min Groundtruth: -55.63	 Max Chan-Vese: 35.33
# Wasserstein loss: -34.44	 Gradient Loss: 0.95	 Min Groundtruth: -41.73	 Max Chan-Vese: 33.30
# Wasserstein loss: -38.02	 Gradient Loss: 1.10	 Min Groundtruth: -47.95	 Max Chan-Vese: 33.42
# Wasserstein loss: -36.08	 Gradient Loss: 0.79	 Min Groundtruth: -43.26	 Max Chan-Vese: 33.09
# ...

# %%
train.train_regulariser(NN, train_clean_image_dataloader, train_cv_image_dataloader,
                       epochs = 100, lr = 0.000001, mu = 10, binary = True, flip = False, device = "cuda:0",
                       save_path = "cuda0_tempnet_3")
# Out:
# Wasserstein loss: -35.23	 Gradient Loss: 0.96	 Min Groundtruth: -43.90	 Max Chan-Vese: 38.06
# Wasserstein loss: -38.79	 Gradient Loss: 0.96	 Min Groundtruth: -43.28	 Max Chan-Vese: 34.86
# Wasserstein loss: -37.52	 Gradient Loss: 0.94	 Min Groundtruth: -33.34	 Max Chan-Vese: 33.55
# Wasserstein loss: -35.11	 Gradient Loss: 1.11	 Min Groundtruth: -56.69	 Max Chan-Vese: 36.23
# Wasserstein loss: -35.03	 Gradient Loss: 0.85	 Min Groundtruth: -39.80	 Max Chan-Vese: 33.29
# Wasserstein loss: -37.15	 Gradient Loss: 0.74	 Min Groundtruth: -44.00	 Max Chan-Vese: 35.04
# Wasserstein loss: -36.36	 Gradient Loss: 1.06	 Min Groundtruth: -52.39	 Max Chan-Vese: 34.49
# Wasserstein loss: -35.56	 Gradient Loss: 1.16	 Min Groundtruth: -47.05	 Max Chan-Vese: 34.72
# Wasserstein loss: -37.51	 Gradient Loss: 1.00	 Min Groundtruth: -49.89	 Max Chan-Vese: 36.21
# Wasserstein loss: -36.10	 Gradient Loss: 1.00	 Min Groundtruth: -49.03	 Max Chan-Vese: 35.07
# ...
